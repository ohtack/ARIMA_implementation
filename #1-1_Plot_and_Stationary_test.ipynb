# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from data_load import *

# %%
price = data['Adj Close']
plt.figure(figsize = (16,5))
plt.plot(price)
plt.grid(True)
plt.title('TESLA Stock Movement')
plt.xlabel("Date", fontsize=14)
plt.ylabel("Stock Price", fontsize=14)
plt.show()

# %%
from pandas.plotting import lag_plot
plt.figure()
plt.figure(figsize = (12,5))
lag_plot(price, lag = 3)
plt.grid(True)
plt.title('TESLA - Autocorrelation plot with lag = 3')

plt.show()

# %% [markdown]
# ##### I can watch autocorrelation in the plot

# %%
from dfTest import *

print("TESLA Stock dickey-fuller test")
print()
dfTest(price)

# Judgment:
# (null-hypothesis: TS is non-stationary)
# p-value < 0.05: reject null-hypothesis –> Stationary
# p-value > 0.05: accept –> non-Stationary
# Out:
# TESLA Stock dickey-fuller test
#
# ADF Statistic: 3.291646404430804
# p-value: 1.0
# Critical Values:
# 1%: -3.439229783394421
# 5%: -2.86545894814762
# 10%: -2.5688568756191392

# %% [markdown]
# ##### Fail to reject the null hypothesis (Ho), which is non-stationary and has some time dependent structure
