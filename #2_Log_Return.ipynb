# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from data_load import *

# %%
price = data['Adj Close']
Ret = price.pct_change().dropna()
plt.figure(figsize=(12, 5))
plt.plot(Ret)
plt.grid(True)
plt.title("TESLA stock daily return")
plt.xlabel("Date")
plt.ylabel("Return")
plt.show()

# %%
from dfTest import *
dfTest(Ret)
# Out:
# ADF Statistic: -14.382756575468159
# p-value: 9.094871048942139e-27
# Critical Values:
# 1%: -3.439075747702915
# 5%: -2.8653910653234655
# 10%: -2.568820711931304

# %% [markdown]
# ##### Reject the null hypothesis (H0) and the data is stationary.

# %% [markdown]
# ## Tesla stock daily log return

# %%
log_Ret = np.log(price / price.shift(1))
log_Ret.head(3)
# Out:
# 0         NaN
# 1    0.019169
# 2    0.019541
# Name: Adj Close, dtype: float64

# %%
plt.figure(figsize=(12, 5))
plt.plot(log_Ret)
plt.grid(True)
plt.title("TESLA stock log daily return")
plt.xlabel("Date")
plt.ylabel("Return")
plt.show()

# %%
plt.hist(log_Ret,60)
print("Log Return dickey-fuller test")
print()
dfTest(log_Ret.dropna()) # drop NA value
# Out:
# Log Return dickey-fuller test
#
# ADF Statistic: -14.390717145081712
# p-value: 8.834254252543407e-27
# Critical Values:
# 1%: -3.439075747702915
# 5%: -2.8653910653234655
# 10%: -2.568820711931304

# %% [markdown]
# ##### Reject the null hypothesis (H0) and the data is stationary.
